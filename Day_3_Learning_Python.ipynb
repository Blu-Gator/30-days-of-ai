# %% [markdown]
# <a href="https://colab.research.google.com/github/Blu-Gator/30-days-of-ai/blob/main/Day_3_Learning_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Day 3: Learning Python")
# Out:
# Day 3: Learning Python

# %%
name = "Archie"
age = 50
height = 5.10
is_training = True
print(name, age, height, is_training)

my_weight = 285
my_goal_weight = 260
my_training_days = 5

workouts = ["Chest", "Back", "Legs", "Shoulders", "Arms"]
print(workouts)
print(workouts[0])     # first item
print(workouts[-1])    # last item

workouts.append("Cardio")
print(workouts)

foods = ["Cheeseburgers", "Sushi","Wings", "Chinese Food", "Pizza"]
print(foods)
print(foods[1])  #second item

for day in workouts:
    print("Training:", day)

numbers = [1, 2, 3, 4, 5]
for num in numbers:
    print(num * 10)

for fave in foods:
  print("Favorite:", fave)

def greet(name):
    return "Hello " + name

print(greet("Archie"))

def double(x):
    return x * 2

print(double(10))

def cut_weight(current):
  return current- 25

cut_weight(285)

weights = [285, 283, 281, 279, 277]
average_weight = sum(weights) / len(weights)
print("Average weight:", average_weight)

ran_nums = [20, 30, 40, 50, 60]
average_num = sum(ran_nums) / len(ran_nums)
print("Average Number:", average_num)
# Out:
# Archie 50 5.1 True
# ['Chest', 'Back', 'Legs', 'Shoulders', 'Arms']
# Chest
# Arms
# ['Chest', 'Back', 'Legs', 'Shoulders', 'Arms', 'Cardio']
# ['Cheeseburgers', 'Sushi', 'Wings', 'Chinese Food', 'Pizza']
# Sushi
# Training: Chest
# Training: Back
# Training: Legs
# Training: Shoulders
# Training: Arms
# Training: Cardio
# 10
# 20
# 30
# 40
# 50
# Favorite: Cheeseburgers
# Favorite: Sushi
# Favorite: Wings
# Favorite: Chinese Food
# Favorite: Pizza
# Hello Archie
# 20
# Average weight: 281.0
# Average Number: 40.0

# %% [markdown]
# What part of Python felt easiest today?
# - The beginning felt easiest because it just dealt with variable values
#
# What part felt confusing or slow?
# - Printing out my favorite foods took awhile to understand.
#
# What can I confidently do now that I couldn't do before?
# - Complete a line of code using Python
